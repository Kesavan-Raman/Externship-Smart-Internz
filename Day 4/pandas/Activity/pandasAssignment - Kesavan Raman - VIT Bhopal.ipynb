# %% [markdown]
# # Pandas Assignment

# %% [raw]
# Name : Kesavan R
# Reg No : 19MIM10086
# College : Vellore Institute of Technology

# %%
import pandas as pd

# %%
#Dataset link : https://www.kaggle.com/kashnitsky/mlcourse?select=telecom_churn.csv

# %%
df = pd.read_csv('telecom_churn.csv')

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df1 = df.head()

# %%
df1
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df2 = df.tail()

# %%
mer = pd.merge(df1,df2,on="State")

# %%
mer
# Out:
# Empty DataFrame
# Columns: [State, Account length_x, Area code_x, International plan_x, Voice mail plan_x, Number vmail messages_x, Total day minutes_x, Total day calls_x, Total day charge_x, Total eve minutes_x, Total eve calls_x, Total eve charge_x, Total night minutes_x, Total night calls_x, Total night charge_x, Total intl minutes_x, Total intl calls_x, Total intl charge_x, Customer service calls_x, Churn_x, Account length_y, Area code_y, International plan_y, Voice mail plan_y, Number vmail messages_y, Total day minutes_y, Total day calls_y, Total day charge_y, Total eve minutes_y, Total eve calls_y, Total eve charge_y, Total night minutes_y, Total night calls_y, Total night charge_y, Total intl minutes_y, Total intl calls_y, Total intl charge_y, Customer service calls_y, Churn_y]
# Index: []
#
# [0 rows x 39 columns]

# %%
df2 = pd.DataFrame({'col1':[2,1,2,3],'col2':[3,24,5,3],'col3':[20,45,23,23]})

# %%
df3 = pd.DataFrame({'col4':[2,13,2,3],'col5':[20,45,23,23],'col6': [3,24,5,3]})

# %%
join = df3.join(df2)

# %%
join
# Out:
#    col4  col5  col6  col1  col2  col3
# 0     2    20     3     2     3    20
# 1    13    45    24     1    24    45
# 2     2    23     5     2     5    23
# 3     3    23     3     3     3    23

# %%
concat = pd.concat([join,df2])

# %%
concat
# Out:
#    col4  col5  col6  col1  col2  col3
# 0   2.0  20.0   3.0     2     3    20
# 1  13.0  45.0  24.0     1    24    45
# 2   2.0  23.0   5.0     2     5    23
# 3   3.0  23.0   3.0     3     3    23
# 0   NaN   NaN   NaN     2     3    20
# 1   NaN   NaN   NaN     1    24    45
# 2   NaN   NaN   NaN     2     5    23
# 3   NaN   NaN   NaN     3     3    23

# %%
#Checkin the null values

# %%
df.isnull()
# Out:
#       State  Account length  Area code  International plan  Voice mail plan  \
# 0     False           False      False               False            False
# 1     False           False      False               False            False
# 2     False           False      False               False            False
# 3     False           False      False               False            False
# 4     False           False      False               False            False
# ...     ...             ...        ...                 ...              ...
# 3328  False           False      False               False            False
# 3329  False           False      False               False            False
# 3330  False           False      False               False            False
# 3331  False           False      False               False            False
# 3332  False           False      False               False            False
#
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.loc[2:6]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
# 5                      0              223.4               98
# 6                     24              218.2               88
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2             41.38              121.2              110             10.30
# ...

# %%
df.iloc[6]
# Out:
# State                        MA
# Account length              121
# Area code                   510
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        24
# Total day minutes         218.2
# Total day calls              88
# Total day charge          37.09
# Total eve minutes         348.5
# Total eve calls             108
# Total eve charge          29.62
# Total night minutes       212.6
# Total night calls           118
# Total night charge         9.57
# Total intl minutes          7.5
# Total intl calls              7
# Total intl charge          2.03
# Customer service calls        3
# Churn                     False
# Name: 6, dtype: object

# %%
df.set_index('State',inplace=True)

# %%
df
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
# ...               ...        ...                ...             ...
# AZ                192        415                 No             Yes
# WV                 68        415                 No              No
# RI                 28        510                 No              No
# CT                184        510                Yes              No
# TN                 74        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1              110
# ...

# %%
df = df.rename(columns={"International plan":"world plan"})

# %%
df
# Out:
#        Account length  Area code world plan Voice mail plan  \
# State
# KS                128        415         No             Yes
# OH                107        415         No             Yes
# NJ                137        415         No              No
# OH                 84        408        Yes              No
# OK                 75        415        Yes              No
# ...               ...        ...        ...             ...
# AZ                192        415         No             Yes
# WV                 68        415         No              No
# RI                 28        510         No              No
# CT                184        510        Yes              No
# TN                 74        415         No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1              110
# OH                        26              161.6              123
# ...

# %%
df.shape
# Out:
# (3333, 19)

# %%
df['Area code']=df['Area code'].fillna(df['Area code'].mean())

# %%
df['Account length']=df['Account length'].fillna(df['Account length'].mean())
